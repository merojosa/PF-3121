# %% [markdown]
# ## Instalación

# %%
# !pip install keras
# !pip install tensorflow

# %% [markdown]
# ## Código completo

# %%
# first neural network with keras tutorial
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
# load the dataset
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]
# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10)
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/150
# 77/77 [==============================] - 0s 692us/step - loss: 26.7340 - accuracy: 0.6510
# Epoch 2/150
# 77/77 [==============================] - 0s 679us/step - loss: 4.0330 - accuracy: 0.5951
# Epoch 3/150
# 77/77 [==============================] - 0s 693us/step - loss: 0.8937 - accuracy: 0.6250
# Epoch 4/150
# 77/77 [==============================] - 0s 718us/step - loss: 0.8391 - accuracy: 0.6380
# Epoch 5/150
# 77/77 [==============================] - 0s 692us/step - loss: 0.8312 - accuracy: 0.6302
# Epoch 6/150
# 77/77 [==============================] - 0s 757us/step - loss: 0.7827 - accuracy: 0.6341
# Epoch 7/150
# 77/77 [==============================] - 0s 711us/step - loss: 0.7401 - accuracy: 0.6406
# Epoch 8/150
# 77/77 [==============================] - 0s 705us/step - loss: 0.7467 - accuracy: 0.6510
# Epoch 9/150
# 77/77 [==============================] - 0s 731us/step - loss: 0.7438 - accuracy: 0.6419
# Epoch 10/150
# ...

# %% [markdown]
# ## Predicciones

# %%
# first neural network with keras make predictions
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
# load the dataset
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]
# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10, verbose=0)
# make class predictions with the model
predictions = (model.predict(X) > 0.5).astype(int)
# summarize the first 5 cases
for i in range(5):
	print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# 24/24 [==============================] - 0s 604us/step
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 0 (expected 1)

# %% [markdown]
# ## Comentarios del ejercicio
#
# - El número de input features se determina con el parámetro input_dim
# - La cantidad de layers que se ocupan se puede averiguar únicamente a prueba y error
# - La cantidad de neuronas se define en el primer parámetro de Dense. El segundo parámetro (activation) funciona para determinar el activation function.
# - IMPORTANTE: El orden de los model.add determina el tipo de layer que va a ser. El primero sería el input layer, los del medio serían hidden layers, y el último sería el output layer.
# - Los demás detalles son más intuitivos
#
# Para un uso profesional, como prueba de concepto puede funcionar montones debido a la facilidad y rapidez de la implementación. Por supuesto, la definición de parámetros y métodos tomarían tiempo ya que habría que comparar la precisión para obtener una combinación que sea provechosa para el caso de uso. Respecto al ejercicio como tal, no tengo muchas quejas honestamente. Me pareción sumamente intuitivo. La única molestia es que quizá la definición de layers (input, hidden, output) no es la más mejor en términos de buenas prácticas de programación. Sin embargo, es decisión de diseño de la librería.
